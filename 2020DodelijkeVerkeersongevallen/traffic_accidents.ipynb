# %%
import matplotlib

font = {'family' : 'sans',
        'weight' : 'normal',
        'size'   : 18}

matplotlib.rc('font', **font)

# %%
import pandas as pd

df = pd.read_csv("data.csv", sep=",")

col_names = df.columns.values
coordinates = df[['X_COORD', 'Y_COORD']].values

print(col_names)
# Out:
# ['_id' 'Jaar' 'LEEFTIJD' 'GESLACHT' 'vervoerwijze' 'vervoerwijzefilter'
#  'wegvak/kruispunt' 'wegbeheerder' 'wegnummer' 'HECTOMETER' 'STRAAT1'
#  'STRAAT2' 'STRAAT3' 'GEMEENTE' 'GEMEENTE 2013' 'PROVINCIE' 'type locatie'
#  'X_COORD' 'Y_COORD' 'latitude' 'longitude']

# %%
P, bins, fig = plt.hist(df['LEEFTIJD'].values, 100, density=True)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 6))
plt.axis(False)
plt.scatter(coordinates[:,0], coordinates[:,1], s=10, alpha=0.1)
plt.show()
